# %%
from pathlib import Path
import numpy as np
import pandas as pd
from natsort import natsorted

thispath = Path.cwd().resolve()

datadir = Path("/mnt/nas4/datasets/ToReadme/ExaMode_Dataset1/AOEC")
maskdir = Path(thispath.parent / "data" / "Mask_PyHIST_v2")

he_csv = np.squeeze(pd.read_csv(Path(maskdir.parent / "lung_data" / "he_images.csv")).to_numpy())
print(he_csv)

svs_files = natsorted([i for i in datadir.rglob("*.svs") if "LungAOEC" in str(i)], key=str)

he_svs_files = []
for name in he_csv:
    for file in svs_files:
        if file.stem in name:
            he_svs_files.append(file)
# Out:
# ['000029269500258388.svs' '000029389200263815.svs'
#  '000029488200270022.svs' ... '000036434500773566.svs'
#  '000036434500773567.svs' '000036434900773056.svs']

# %%
list1 = []
list2 = []
list3 = []
for file in he_svs_files:
    if "LungAOEC_List1" in str(file):
        list1.append(file)
    elif "LungAOEC_List2" in str(file):
        list2.append(file)
    elif "LungAOEC_List3" in str(file):
        list3.append(file)

print(len(list1))
print(len(list2))
print(len(list3))
# Out:
# 595
# 643
# 80

# %%
from tqdm import tqdm


datadir = Path(thispath.parent / "data")

pyhistdir = Path(datadir / "Mask_PyHIST_v2")

test_path = natsorted([i for i in pyhistdir.rglob("*_densely_filtered_paths.csv") if "Lung" in str(i) and "LungAOEC" not in str(i)])

number_patches = 0
path_patches_test = {}
for wsi_patches in tqdm(test_path, desc="Selecting patches to extract features"):

    csv_instances = pd.read_csv(wsi_patches).to_numpy()
    
    number_patches = number_patches + len(csv_instances)
    name = wsi_patches.parent.stem
    path_patches_test[name] = csv_instances
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       6 datadir = Path(thispath.parent / "data")
#       8 pyhistdir = Path(datadir / "Mask_PyHIST_v2")
# ---> 10 test_path = natsorted([i for i in pyhistdir.rglob("*_densely_filtered_paths.csv") if "Lung" in str(i) and "LungAOEC" not in str(i)])
#      12 number_patches = 0
#      13 path_patches_test = {}
#
# NameError: name 'natsorted' is not defined

# %%
print(path_patches_test)

# %%
from pathlib import Path

thispath = Path.cwd().resolve()

datadir = Path(thispath.parent / "data")

import pandas as pd
pd.read_csv(datadir / "features.csv", index_col=0)
# Out:
#                                        0          1          2         3  \
# 000029269500258388_0420.png']  -1.874369  12.824915  -7.927593 -3.888893
# 000029269500258388_0565.png'] -10.650686  10.267938  -8.855888 -2.248634
# 000029269500258388_0566.png']  -9.842843  12.125648 -11.520831 -5.091084
# 000029269500258388_0709.png']  -8.764344   6.942096  -5.016758 -4.136411
# 000029269500258388_0710.png'] -10.764772  12.359644  -7.862501 -5.538715
# ...                                  ...        ...        ...       ...
# 000036434900773056_6996.png']   8.577295   1.774930  -6.665796 -2.944678
# 000036434900773056_6997.png']   8.300350   1.905122  -5.031601 -2.228056
# 000036434900773056_6998.png']   6.353098   2.303749  -4.952878 -3.954876
# 000036434900773056_6999.png']   5.945761  -3.080816  -4.540818 -4.284637
# 000036434900773056_7000.png']   4.476303   5.916679  -3.549381 -3.391332
#
#                                       4         5         6         7  \
# 000029269500258388_0420.png'] -4.155449 -5.533926  7.063107  8.258136
# 000029269500258388_0565.png']  3.378276  8.267600 -2.538938  6.178774
# 000029269500258388_0566.png']  0.796871  4.093986  5.948261  2.436406
# 000029269500258388_0709.png']  2.290087 -0.680631  4.080369  1.198424
# 000029269500258388_0710.png']  1.668338 -0.655643  4.933144  3.858293
# ...                                 ...       ...       ...       ...
# 000036434900773056_6996.png'] -1.787900 -4.385535 -3.321821 -0.752891
# 000036434900773056_6997.png'] -1.858400 -3.943346 -3.414038 -1.165892
# 000036434900773056_6998.png']  1.813366 -4.451097  0.327267 -3.081097
# 000036434900773056_6999.png'] -0.320771 -3.624620 -7.618742 -3.611231
# 000036434900773056_7000.png'] -4.288767 -0.535231  2.407932  7.152344
#
#                                        8          9  ...       118       119  \
# 000029269500258388_0420.png']  -5.234848   9.714290  ...  1.582723 -8.773753
# 000029269500258388_0565.png'] -10.954339   7.405748  ...  2.135234 -2.551850
# 000029269500258388_0566.png']  -6.308151  14.703712  ... -0.256060 -3.199579
# 000029269500258388_0709.png']  -3.767809   5.217839  ...  4.270081 -1.176525
# 000029269500258388_0710.png']  -4.400155   6.603542  ...  2.196808  2.755233
# ...                                  ...        ...  ...       ...       ...
# 000036434900773056_6996.png']  -0.185159   1.194386  ... -0.783617  3.742828
# 000036434900773056_6997.png']   2.741154   1.233819  ... -0.736273  6.188923
# 000036434900773056_6998.png']   0.063247   2.004411  ... -1.357373  4.364039
# 000036434900773056_6999.png']   0.995382  -2.294022  ... -3.548571  4.634526
# 000036434900773056_7000.png']  -3.935255  -0.114861  ...  3.090715 -3.306881
#
#                                      120        121       122        123  \
# 000029269500258388_0420.png'] -13.524282  12.451608 -5.186311  13.815020
# 000029269500258388_0565.png'] -17.991184   2.918725  8.191652  16.423773
# 000029269500258388_0566.png'] -19.254965   5.098068  6.831156   8.331860
# 000029269500258388_0709.png'] -15.061872   3.029719  9.510625   8.658572
# 000029269500258388_0710.png'] -14.724010   9.757512  8.726346  10.498937
# ...                                  ...        ...       ...        ...
# 000036434900773056_6996.png']  -5.909368   2.863943  0.411565   2.554628
# 000036434900773056_6997.png']  -4.267274   5.306023 -1.290567   4.830193
# 000036434900773056_6998.png']  -4.282294   4.186924  2.335672   2.862978
# 000036434900773056_6999.png']  -2.435277  -3.046665  5.775188   7.003904
# 000036434900773056_7000.png']  -6.114620   9.264454 -6.663635   3.557784
#
#                                      124       125       126       127
# 000029269500258388_0420.png']  13.096638 -3.975429 -6.107109 -7.202345
# 000029269500258388_0565.png']   8.616478  3.227475  1.041443 -5.541319
# 000029269500258388_0566.png']  16.149553  2.421165 -2.900798  5.560798
# 000029269500258388_0709.png']  11.835220 -0.712148 -4.812952  0.452570
# 000029269500258388_0710.png']   7.832247  3.414295 -8.139396  5.237278
# ...                                  ...       ...       ...       ...
# 000036434900773056_6996.png']   3.357322  0.441338  3.255774 -4.123902
# 000036434900773056_6997.png']   7.388474  0.043204  1.276887 -2.646002
# 000036434900773056_6998.png']   4.488457  0.330979 -1.284775 -0.089645
# 000036434900773056_6999.png']   5.185667 -1.491675  7.355977 -3.422288
# 000036434900773056_7000.png']   5.678079 -3.241453 -1.931342 -9.166661
#
# [2443635 rows x 128 columns]

# %%
from pathlib import Path

thispath = Path.cwd().resolve()

datadir = Path(thispath.parent / "data")
pyhistdir = Path(datadir / "Mask_PyHIST_v2")

import pandas as pd
df = pd.read_csv(pyhistdir / "metadata_slides.csv", index_col=0)

if (df['number_filtered_patches'] == 0).any():
    print("True")

for index, row in df.iterrows():
    if row['number_filtered_patches'] == 0:
        print(index)
# Out:
# True
# 30688300333997
# 31016200350116

# %%
import numpy as np

# Train and validation metrics from saved predictions
modeldir = Path(thispath.parent / "trained_models" / "MIL" / "MIL_resnet101_00025_2102030")


bestdir = Path(modeldir / "10" / "resnet101")

labels = pd.read_csv(datadir / "labels.csv", index_col=0)
train_predictions_df = pd.read_csv(bestdir / "training_predictions_best.csv", index_col="filenames")
train_predictions_df.sort_index(inplace=True)
train_predictions_df.drop(columns=train_predictions_df.columns[0], axis=1, inplace=True)
train_predictions_df = train_predictions_df[~train_predictions_df.index.duplicated(keep='first')]
train_pred_scores = train_predictions_df.values
train_pred = np.where(train_pred_scores > 0.5, 1, 0)

valid_predictions_df = pd.read_csv(bestdir / "validation_predictions_best.csv", index_col="filenames")
valid_predictions_df.sort_index(inplace=True)
valid_predictions_df.drop(columns=valid_predictions_df.columns[0], axis=1, inplace=True)
valid_predictions_df = valid_predictions_df[~valid_predictions_df.index.duplicated(keep='first')]
valid_pred_scores = valid_predictions_df.values
valid_pred = np.where(valid_pred_scores > 0.5, 1, 0)

wsi_train = labels.index.intersection(train_predictions_df.index)
labels_train = labels.loc[wsi_train].values
wsi_valid = labels.index.intersection(valid_predictions_df.index)
labels_valid = labels.loc[wsi_valid].values

labels_train_flat = labels_train.flatten()
train_pred_flat = train_pred.flatten()
labels_valid_flat = labels_valid.flatten()
valid_pred_flat = valid_pred.flatten()

arange_like_train = np.arange(len(labels_train_flat))
arange_like_valid = np.arange(len(labels_valid_flat))

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score, cohen_kappa_score
names = ["SCC", "NSCC_Adeno", "NSCC_Squamous", "Normal"]
for i in range(4):
            
            accuracy = accuracy_score(labels_valid_flat[arange_like_valid%4 == 0 + i],
                                    valid_pred_flat[arange_like_valid%4 == 0 + i])

            print("== Final Metrics ==")
            print(f"Accuracy {names[i]} = {accuracy:0.2f}")

            bma = balanced_accuracy_score(labels_valid_flat[arange_like_valid%4 == 0 + i],
                                          valid_pred_flat[arange_like_valid%4 == 0 + i])
            kappa = cohen_kappa_score(labels_valid_flat[arange_like_valid%4 == 0 + i],
                                    valid_pred_flat[arange_like_valid%4 == 0 + i])
            print(f"BMA {names[i]} = {bma:0.2f}")
            print(f"Kappa {names[i]} = {kappa:0.2f}")
# Out:
# == Final Metrics ==
# Accuracy SCC = 0.83
# BMA SCC = 0.62
# Kappa SCC = 0.29
# == Final Metrics ==
# Accuracy NSCC_Adeno = 0.74
# BMA NSCC_Adeno = 0.74
# Kappa NSCC_Adeno = 0.47
# == Final Metrics ==
# Accuracy NSCC_Squamous = 0.82
# BMA NSCC_Squamous = 0.63
# Kappa NSCC_Squamous = 0.31
# == Final Metrics ==
# Accuracy Normal = 0.80
# BMA Normal = 0.68
# Kappa Normal = 0.41
